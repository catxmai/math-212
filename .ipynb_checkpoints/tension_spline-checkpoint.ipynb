# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True

# bunch of points t0, .., tn and y0,...,yn
# car
# t = [-1.5,1,2,20,32,40,53,60,65,70,72,75]
# y = [0,1,4,8,15,15,15,9,8,7,2,1]

# shark
t = [-1,1,8,14,20,25,30,32,34,36,40,43,46,47,47.75,48,49,52,55,59,63,70,73,77,79,83,84,85,86,87,88]
y = [0,2,5,6.5,8,8.5,9,10,12,15,21,25,28,22,16,12,10,9.5,9,8.5,7.5,5,4,5.5,8,13,15,13,10,5,1]
print(len(t))

tau = 0.25
assert t==sorted(t)
assert len(t) == len(y)
n = len(t)-1
h, a, b, g = [0]*n, [0]*n, [0]*n, [0]*n

for i in range(n):
    h[i] = t[i+1] - t[i]
    g[i] = tau**2 *(y[i+1] - y[i])/h[i]
    a[i] = 1/h[i] - tau/np.sinh(tau*h[i])
    b[i] = tau*np.cosh(tau*h[i])/np.sinh(tau*h[i]) - 1/h[i]
    

sys = np.zeros((n+1,n+1))
for row in range(1,n):
    sys[row][row-1] = a[row-1]
    sys[row][row] = b[row-1] + b[row]
    sys[row][row+1] = a[row]
sys[0][0] = 1
sys[n][n] = 1

beta = np.zeros((n+1,1))
for i in range(1, n):
    beta[i][0] = g[i] - g[i-1]

beta = np.asmatrix(beta)
sys = np.asmatrix(sys)
z = np.linalg.inv(sys)*beta


def f(x,i):
    t1 = (z[i]*np.sinh(tau*(t[i+1]-x))) + (z[i+1]*np.sinh(tau*(x-t[i])))
    t1 = t1/(tau**2 * np.sinh(tau*h[i]))
    t2 = (y[i]-z[i]/tau**2)*(t[i+1]-x)/h[i]
    t3 = (y[i+1]-z[i+1]/tau**2)*(x-t[i])/h[i]
    return float(t1+t2+t3)

fx,fy = [],[]
for i in range(n):
    x_vals = np.arange(t[i], t[i+1], .01)
    y_vals = [f(x,i) for x in x_vals]
    for x in x_vals:
        fx.append(x)
    for ys in y_vals:
        fy.append(ys)
plt.figure(figsize=(12,6))
plt.scatter(fx,fy,s=1,rasterized=True)
plt.title(r'$\tau$ = ' + str(tau), fontsize=35)
plt.tight_layout()
plt.savefig(f"topcar_tau{tau}.svg", format="svg", dpi=200)
# Out:
# 31

# %%
li = [0]*4
li
# Out:
# [0, 0, 0, 0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# bunch of points t0, .., tn and y0,...,yn
t = [-1.5,-1,1,4,8,10,5,14,17.5,20,40,49,51.5,55,58.5,61,70,72,74.5,75]
y = [0,-3,-4,-4.5,-6,-9,-10,-9,-9,-6,-6,-6,-9,-10,-9,-6,-6,-4,-3,1]



tau = 10
assert len(t) == len(y)
n = len(t)-1
h, a, b, g = [0 for i in range(n)], [0 for i in range(n)], [0 for i in range(n)], [0 for i in range(n)]

for i in range(n):
    h[i] = t[i+1] - t[i]
    g[i] = tau**2 *(y[i+1] - y[i])/h[i]
    a[i] = 1/h[i] - tau/np.sinh(tau*h[i])
    b[i] = tau*np.cosh(tau*h[i])/np.sinh(tau*h[i]) - 1/h[i]
    

sys = np.zeros((n+1,n+1))
for row in range(1,n):
    sys[row][row-1] = a[i-1]
    sys[row][row] = b[i-1] + b[i]
    sys[row][row+1] = a[i]
sys[0][0] = 1
sys[n][n] = 1

beta = np.zeros((n+1,1))
for i in range(1, n):
    beta[i][0] = g[i] - g[i-1]

beta = np.asmatrix(beta)
sys = np.asmatrix(sys)
z = np.linalg.inv(sys)*beta


def f(x,i):
    t1 = (z[i]*np.sinh(tau*(t[i+1]-x))) + (z[i+1]*np.sinh(tau*(x-t[i])))
    t1 = t1/(tau**2 * np.sinh(tau*h[i]))
    t2 = (y[i]-z[i]/tau**2)*(t[i+1]-x)/h[i]
    t3 = (y[i+1]-z[i+1]/tau**2)*(x-t[i])/h[i]
    return float(t1 + t2 + t3)

fx,fy = [],[]
for i in range(n):
    x_vals = np.arange(t[i], t[i+1], .005)
    y_vals = [f(x,i) for x in x_vals]
    for x in x_vals:
        fx.append(x)
    for ys in y_vals:
        fy.append(ys)
plt.figure(figsize=(15,6))
plt.scatter(fx,fy)

# %%
len(t)
# Out:
# 20
